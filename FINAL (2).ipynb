# %%
# print all the outputs in a cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
import numpy as np

# %%
BB=pd.read_csv('baseball_stats.csv')
W=pd.read_csv('Denver_Weather.csv')
BB.replace('D',1.0, inplace=True)
BB.replace('N',0.0, inplace=True)
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (14,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
BB[BB.Home=='COL']
# Out:
#             Date Day of Week Visitor Visitor Division Home Home Division  \
# 51     4/10/2009         Fri     PHI               NL  COL            NL
# 66     4/11/2009         Sat     PHI               NL  COL            NL
# 81     4/12/2009         Sun     PHI               NL  COL            NL
# 229    4/24/2009         Fri     LAN               NL  COL            NL
# 244    4/25/2009         Sat     LAN               NL  COL            NL
# 259    4/26/2009         Sun     LAN               NL  COL            NL
# 275    4/27/2009         Mon     SDN               NL  COL            NL
# 288    4/28/2009         Tue     SDN               NL  COL            NL
# 304    4/29/2009         Wed     SDN               NL  COL            NL
# 396     5/6/2009         Wed     SFN               NL  COL            NL
# 410     5/7/2009         Thu     SFN               NL  COL            NL
# 426     5/8/2009         Fri     FLO               NL  COL            NL
# ...

# %%
COL=BB.loc[BB.Home=='COL']
list(COL.columns)
COL
# Out:
# ['Date',
#  'Day of Week',
#  'Visitor',
#  'Visitor Division',
#  'Home',
#  'Home Division',
#  'Visitor Score',
#  'Home Score',
#  'Game Length (outs)',
#  'Day or Night',
#  'If Completed at Later Date',
#  'Stadium ID',
#  'Attendance',
#  'Game Length (minutes)',
#  'Visitor Runs (by inning)',
#  'Home Runs (by inning)',
#  'Visitor At-Bats',
#  'Visitor Hits',
#  'Visitor Doubles',
#  'Visitor Triples',
#  'Visitor Homeruns',
#  'Visitor RBIs',
#  'Visitor Sacrifice Hits',
#  'Visitor Sacrifice Flies',
#  'Visitor HBP',
#  'Visitor Walks',
#  'Visitor Walks (intentional)',
#  'Visitor Strikeouts',
#  'Visitor Stolen Bases',
#  'Visitor Caught Stealing',
#  'Visitor Ground into Double Play',
#  'Visitor Awarded First (interference)',
#  'Visitor Left on Base',
#  'Visitor Pitchers Used',
#  'Visitor Earned Runs (individual)',
#  'Visitor Earned Runs (team)',
#  'Visitor Wild Pitch',
#  'Visitor Balks',
#  'Visitor Outs',
#  'Visitor Assists',
#  'Visitor Errors',
# ...

# %%
W.columns=['ObsDate',
 'ActHigh',
 'ActLow',
 'ActAvg',
 'NormHigh',
 'NormLow',
 'NormAvg.',
 'NormDept',
 'RecHigh',
 'RecYear',
 'RecLow',
 'RecYear1',
 'PrecipAmt',
 'SnowAmt',
 'SnowGround',
 'HeatDegDay',
 'CoolDegDay',
 'Unnamed: 17']

# %%
W.ObsDate = pd.to_datetime(W.ObsDate)
COL.Date = pd.to_datetime(COL.Date)
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
W.ObsDate.head()
COL.Date.head()
# Out:
# 0   2009-04-01
# 1   2009-04-02
# 2   2009-04-03
# 3   2009-04-04
# 4   2009-04-05
# Name: ObsDate, dtype: datetime64[ns]
# 51    2009-04-10
# 66    2009-04-11
# 81    2009-04-12
# 229   2009-04-24
# 244   2009-04-25
# Name: Date, dtype: datetime64[ns]

# %%
month=W.ObsDate.astype('datetime64[M]')

# %%
W['Month']=W.ObsDate.astype('datetime64[M]')
COL['Month']=COL.Date.astype('datetime64[M]')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
W.head()
COL.head()
W.drop('NormLow',axis=1,inplace=True)
W.drop('RecHigh',axis=1,inplace=True)
W.drop('RecYear',axis=1,inplace=True)
W.drop('RecLow',axis=1,inplace=True)
W.drop('RecYear1',axis=1,inplace=True)
W.drop('SnowGround',axis=1,inplace=True)
W.drop('HeatDegDay',axis=1,inplace=True)
W.drop('CoolDegDay',axis=1,inplace=True)
W.drop('Unnamed: 17',axis=1,inplace=True)
# Out:
#      ObsDate  ActHigh  ActLow  ActAvg  NormHigh  NormLow  NormAvg.  NormDept  \
# 0 2009-04-01       46      23      35        61       32        46       -11
# 1 2009-04-02       55      19      37        61       32        46        -9
# 2 2009-04-03       55      32      44        61       32        47        -3
# 3 2009-04-04       32      19      26        61       32        47       -21
# 4 2009-04-05       34      18      26        62       32        47       -21
#
#   RecHigh RecYear RecLow RecYear1 PrecipAmt  SnowAmt  SnowGround  HeatDegDay  \
# 0       M       M      M        M      0.17      0.7         4.0          30
# 1       M       M      M        M       0.1      0.0         3.0          28
# 2       M       M      M        M       0.3      0.4         3.0          21
# 3       M       M      M        M       0.4      1.8         4.0          39
# 4       M       M      M        M      0.04      0.4         5.0          39
#
#    CoolDegDay  Unnamed: 17      Month
# ...

# %%
COL.drop('If Completed at Later Date',axis=1,inplace=True)
COL.drop('Stadium ID',axis=1,inplace=True)
COL.drop('Visitor Runs (by inning)',axis=1,inplace=True)
COL.drop('Home Runs (by inning)',axis=1,inplace=True)
COL.drop('Visitor At-Bats',axis=1,inplace=True)
COL.drop('Visitor Hits',axis=1,inplace=True)
COL.drop('Visitor Doubles',axis=1,inplace=True)
COL.drop('Visitor Triples',axis=1,inplace=True)
COL.drop('Visitor RBIs',axis=1,inplace=True)
COL.drop('Visitor Sacrifice Hits',axis=1,inplace=True)
COL.drop('Visitor Sacrifice Flies',axis=1,inplace=True)
COL.drop('Visitor HBP',axis=1,inplace=True)
COL.drop('Visitor Walks',axis=1,inplace=True)
COL.drop('Visitor Walks (intentional)',axis=1,inplace=True)
COL.drop('Visitor Strikeouts',axis=1,inplace=True)
COL.drop('Visitor Stolen Bases',axis=1,inplace=True)
COL.drop('Visitor Caught Stealing',axis=1,inplace=True)
COL.drop('Visitor Ground into Double Play',axis=1,inplace=True)
COL.drop('Visitor Awarded First (interference)',axis=1,inplace=True)
COL.drop('Visitor Left on Base',axis=1,inplace=True)
COL.drop('Visitor Earned Runs (individual)',axis=1,inplace=True)
COL.drop('Visitor Earned Runs (team)',axis=1,inplace=True)
COL.drop('Visitor Wild Pitch',axis=1,inplace=True)
COL.drop('Visitor Balks',axis=1,inplace=True)
COL.drop('Visitor Outs',axis=1,inplace=True)
COL.drop('Visitor Assists',axis=1,inplace=True)
COL.drop('Visitor Passed Balls',axis=1,inplace=True)
COL.drop('Visitor Double Plays',axis=1,inplace=True)
COL.drop('Visitor Triple Plays',axis=1,inplace=True)
COL.drop('Home At-Bats',axis=1,inplace=True)
COL.drop('Home Hits',axis=1,inplace=True)
COL.drop('Home Doubles',axis=1,inplace=True)
COL.drop('Home Triples',axis=1,inplace=True)
COL.drop('Home RBIs',axis=1,inplace=True)
COL.drop('Home Sacrifice Hits',axis=1,inplace=True)
COL.drop('Home Sacrifice Flies',axis=1,inplace=True)
COL.drop('Home Hit by Pitch',axis=1,inplace=True)
COL.drop('Home Walks',axis=1,inplace=True)
COL.drop('Home Walks (intentional)',axis=1,inplace=True)
COL.drop('Home Strikeouts',axis=1,inplace=True)
COL.drop('Home Stolen Bases',axis=1,inplace=True)
COL.drop('Home Caught Stealing',axis=1,inplace=True)
COL.drop('Home Grounded into Double Play',axis=1,inplace=True)
COL.drop('Home Awarded First (interference)',axis=1,inplace=True)
COL.drop('Home Left on Base',axis=1,inplace=True)
COL.drop('Home Earned Runs (individual)',axis=1,inplace=True)
COL.drop('Home Earned Runs (Team)',axis=1,inplace=True)
COL.drop('Home Wild Pitches',axis=1,inplace=True)
COL.drop('Home Balks',axis=1,inplace=True)
COL.drop('Home Outs',axis=1,inplace=True)
COL.drop('Home Assists',axis=1,inplace=True)
COL.drop('Home Passed Balls',axis=1,inplace=True)
COL.drop('Home Double Plays',axis=1,inplace=True)
COL.drop('Home Triple Plays',axis=1,inplace=True)
COL.drop('Acquisition Info',axis=1,inplace=True)
COL.drop('Visitor Division',axis=1,inplace=True)
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
COL.set_index('Date',inplace=True)
W.set_index('ObsDate',inplace=True)
COW=COL.merge(W,left_on='Date',right_index=True)

# %%
April2009 = W.loc[W.Month=="2009-04-01",]
May2009= W.loc[W.Month=="2009-05-01",]
June2009= W.loc[W.Month=="2009-06-01",]
July2009= W.loc[W.Month=="2009-07-01",]
August2009= W.loc[W.Month=="2009-08-01",]
September2009 = W.loc[W.Month=="2009-09-01",]
October2009 = W.loc[W.Month=="2009-10-01",]

April2010 = W.loc[W.Month=="2010-04-01",]
May2010= W.loc[W.Month=="2010-05-01",]
June2010= W.loc[W.Month=="2010-06-01",]
July2010= W.loc[W.Month=="2010-07-01",]
August2010= W.loc[W.Month=="2010-08-01",]
September2010 = W.loc[W.Month=="2010-09-01",]
October2010 = W.loc[W.Month=="2010-10-01",]

April2011 = W.loc[W.Month=="2011-04-01",]
May2011= W.loc[W.Month=="2011-05-01",]
June2011= W.loc[W.Month=="2011-06-01",]
July2011= W.loc[W.Month=="2011-07-01",]
August2011= W.loc[W.Month=="2011-08-01",]
September2011 = W.loc[W.Month=="2011-09-01",]
October2011 = W.loc[W.Month=="2011-10-01",]

April2012 = W.loc[W.Month=="2012-04-01",]
May2012= W.loc[W.Month=="2012-05-01",]
June2012= W.loc[W.Month=="2012-06-01",]
July2012= W.loc[W.Month=="2012-07-01",]
August2012= W.loc[W.Month=="2012-08-01",]
September2012 = W.loc[W.Month=="2012-09-01",]
October2012 = W.loc[W.Month=="2012-10-01",]

April2013 = W.loc[W.Month=="2013-04-01",]
May2013= W.loc[W.Month=="2013-05-01",]
June2013= W.loc[W.Month=="2013-06-01",]
July2013= W.loc[W.Month=="2013-07-01",]
August2013= W.loc[W.Month=="2013-08-01",]
September2013 = W.loc[W.Month=="2013-09-01",]
October2013 = W.loc[W.Month=="2013-10-01",]

April2014 = W.loc[W.Month=="2014-04-01",]
May2014= W.loc[W.Month=="2014-05-01",]
June2014= W.loc[W.Month=="2014-06-01",]
July2014= W.loc[W.Month=="2014-07-01",]
August2014= W.loc[W.Month=="2014-08-01",]
September2014 = W.loc[W.Month=="2014-09-01",]
October2014 = W.loc[W.Month=="2014-10-01",]

April2015 = W.loc[W.Month=="2015-04-01",]
May2015= W.loc[W.Month=="2015-05-01",]
June2015= W.loc[W.Month=="2015-06-01",]
July2015= W.loc[W.Month=="2015-07-01",]
August2015= W.loc[W.Month=="2015-08-01",]
September2015 = W.loc[W.Month=="2015-09-01",]
October2015 = W.loc[W.Month=="2015-10-01",]

April2016 = W.loc[W.Month=="2016-04-01",]
May2016= W.loc[W.Month=="2016-05-01",]
June2016= W.loc[W.Month=="2016-06-01",]
July2016= W.loc[W.Month=="2016-07-01",]
August2016= W.loc[W.Month=="2016-08-01",]
September2016 = W.loc[W.Month=="2016-09-01",]
October2016 = W.loc[W.Month=="2016-10-01",]

April2017 = W.loc[W.Month=="2017-04-01",]
May2017= W.loc[W.Month=="2017-05-01",]
June2017= W.loc[W.Month=="2017-06-01",]
July2017= W.loc[W.Month=="2017-07-01",]
August2017= W.loc[W.Month=="2017-08-01",]
September2017 = W.loc[W.Month=="2017-09-01",]
October2017 = W.loc[W.Month=="2017-10-01",]

April2018 = W.loc[W.Month=="2018-04-01",]
May2018= W.loc[W.Month=="2018-05-01",]
June2018= W.loc[W.Month=="2018-06-01",]
July2018= W.loc[W.Month=="2018-07-01",]
August2018= W.loc[W.Month=="2018-08-01",]
September2018 = W.loc[W.Month=="2018-09-01",]
October2018 = W.loc[W.Month=="2018-10-01",]

# %%
COL.head()
# Out:
#            Day of Week Visitor Home Home Division  Visitor Score  Home Score  \
# Date
# 2009-04-10         Fri     PHI  COL            NL              3          10
# 2009-04-11         Sat     PHI  COL            NL              8           4
# 2009-04-12         Sun     PHI  COL            NL              7           5
# 2009-04-24         Fri     LAN  COL            NL              6           5
# 2009-04-25         Sat     LAN  COL            NL              6           5
#
#             Game Length (outs)  Day or Night  Attendance  \
# Date
# 2009-04-10                  51           1.0     49427.0
# 2009-04-11                  54           0.0     35251.0
# 2009-04-12                  54           1.0     21628.0
# 2009-04-24                  54           0.0     36151.0
# 2009-04-25                  54           0.0     31476.0
#
#             Game Length (minutes)  Visitor Homeruns  Visitor Pitchers Used  \
# Date
# ...

# %%
April2009B = COL.loc[COL.Month=="2009-04-01",]
May2009B= COL.loc[COL.Month=="2009-05-01",]
June2009B= COL.loc[COL.Month=="2009-06-01",]
July2009B= COL.loc[COL.Month=="2009-07-01",]
August2009B= COL.loc[COL.Month=="2009-08-01",]
September2009B = COL.loc[COL.Month=="2009-09-01",]
October2009B = COL.loc[COL.Month=="2009-10-01",]

April2010B = COL.loc[COL.Month=="2010-04-01",]
May2010B= COL.loc[COL.Month=="2010-05-01",]
June2010B= COL.loc[COL.Month=="2010-06-01",]
July2010B= COL.loc[COL.Month=="2010-07-01",]
August2010B= COL.loc[COL.Month=="2010-08-01",]
September2010B = COL.loc[COL.Month=="2010-09-01",]
October2010B = COL.loc[COL.Month=="2010-10-01",]

April2011B = COL.loc[COL.Month=="2011-04-01",]
May2011B= COL.loc[COL.Month=="2011-05-01",]
June2011B= COL.loc[COL.Month=="2011-06-01",]
July2011B= COL.loc[COL.Month=="2011-07-01",]
August2011B= COL.loc[COL.Month=="2011-08-01",]
September2011B = COL.loc[COL.Month=="2011-09-01",]
October2011B = COL.loc[COL.Month=="2011-10-01",]

April2012B = COL.loc[COL.Month=="2012-04-01",]
May2012B= COL.loc[COL.Month=="2012-05-01",]
June2012B= COL.loc[COL.Month=="2012-06-01",]
July2012B= COL.loc[COL.Month=="2012-07-01",]
August2012B= COL.loc[COL.Month=="2012-08-01",]
September2012B = COL.loc[COL.Month=="2012-09-01",]
October2012B = COL.loc[COL.Month=="2012-10-01",]

April2013B = COL.loc[COL.Month=="2013-04-01",]
May2013B= COL.loc[COL.Month=="2013-05-01",]
June2013B= COL.loc[COL.Month=="2013-06-01",]
July2013B= COL.loc[COL.Month=="2013-07-01",]
August2013B= COL.loc[COL.Month=="2013-08-01",]
September2013B = COL.loc[COL.Month=="2013-09-01",]
October2013B = COL.loc[COL.Month=="2013-10-01",]

April2014B = COL.loc[COL.Month=="2014-04-01",]
May2014B= COL.loc[COL.Month=="2014-05-01",]
June2014B= COL.loc[COL.Month=="2014-06-01",]
July2014B= COL.loc[COL.Month=="2014-07-01",]
August2014B= COL.loc[COL.Month=="2014-08-01",]
September2014B = COL.loc[COL.Month=="2014-09-01",]
October2014B = COL.loc[COL.Month=="2014-10-01",]

April2015B = COL.loc[COL.Month=="2015-04-01",]
May2015B= COL.loc[COL.Month=="2015-05-01",]
June2015B= COL.loc[COL.Month=="2015-06-01",]
July2015B= COL.loc[COL.Month=="2015-07-01",]
August2015B= COL.loc[COL.Month=="2015-08-01",]
September2015B = COL.loc[COL.Month=="2015-09-01",]
October2015B = COL.loc[COL.Month=="2015-10-01",]

April2016B = COL.loc[COL.Month=="2016-04-01",]
May2016B= COL.loc[COL.Month=="2016-05-01",]
June2016B= COL.loc[COL.Month=="2016-06-01",]
July2016B= COL.loc[COL.Month=="2016-07-01",]
August2016B= COL.loc[COL.Month=="2016-08-01",]
September2016B = COL.loc[COL.Month=="2016-09-01",]
October2016B = COL.loc[COL.Month=="2016-10-01",]

April2017B = COL.loc[COL.Month=="2017-04-01",]
May2017B= COL.loc[COL.Month=="2017-05-01",]
June2017B= COL.loc[COL.Month=="2017-06-01",]
July2017B= COL.loc[COL.Month=="2017-07-01",]
August2017B= COL.loc[COL.Month=="2017-08-01",]
September2017B = COL.loc[COL.Month=="2017-09-01",]
October2017B = COL.loc[COL.Month=="2017-10-01",]

April2018B = COL.loc[COL.Month=="2018-04-01",]
May2018B= COL.loc[COL.Month=="2018-05-01",]
June2018B= COL.loc[COL.Month=="2018-06-01",]
July2018B= COL.loc[COL.Month=="2018-07-01",]
August2018B= COL.loc[COL.Month=="2018-08-01",]
September2018B = COL.loc[COL.Month=="2018-09-01",]
October2018B = COL.loc[COL.Month=="2018-10-01",]

# %%
COW.head()
COW.rename(columns={'Month_x':'Month'}, inplace=True)
COW.drop('Month_y',axis=1,inplace=True)
# Out:
#            Day of Week Visitor Home Home Division  Visitor Score  Home Score  \
# Date
# 2009-04-10         Fri     PHI  COL            NL              3          10
# 2009-04-11         Sat     PHI  COL            NL              8           4
# 2009-04-12         Sun     PHI  COL            NL              7           5
# 2009-04-24         Fri     LAN  COL            NL              6           5
# 2009-04-25         Sat     LAN  COL            NL              6           5
#
#             Game Length (outs)  Day or Night  Attendance  \
# Date
# 2009-04-10                  51           1.0     49427.0
# 2009-04-11                  54           0.0     35251.0
# 2009-04-12                  54           1.0     21628.0
# 2009-04-24                  54           0.0     36151.0
# 2009-04-25                  54           0.0     31476.0
#
#             Game Length (minutes)  ...    Month_x  ActHigh  ActLow  ActAvg  \
# Date                               ...
# ...

# %%
April2009W = COW.loc[COW.Month=="2009-04-01",]
May2009W= COW.loc[COW.Month=="2009-05-01",]
June2009W= COW.loc[COW.Month=="2009-06-01",]
July2009W= COW.loc[COW.Month=="2009-07-01",]
August2009W= COW.loc[COW.Month=="2009-08-01",]
SeptemWer2009W = COW.loc[COW.Month=="2009-09-01",]
OctoWer2009W = COW.loc[COW.Month=="2009-10-01",]

April2010W = COW.loc[COW.Month=="2010-04-01",]
May2010W= COW.loc[COW.Month=="2010-05-01",]
June2010W= COW.loc[COW.Month=="2010-06-01",]
July2010W= COW.loc[COW.Month=="2010-07-01",]
August2010W= COW.loc[COW.Month=="2010-08-01",]
SeptemWer2010W = COW.loc[COW.Month=="2010-09-01",]
OctoWer2010W = COW.loc[COW.Month=="2010-10-01",]

April2011W = COW.loc[COW.Month=="2011-04-01",]
May2011W= COW.loc[COW.Month=="2011-05-01",]
June2011W= COW.loc[COW.Month=="2011-06-01",]
July2011W= COW.loc[COW.Month=="2011-07-01",]
August2011W= COW.loc[COW.Month=="2011-08-01",]
SeptemWer2011W = COW.loc[COW.Month=="2011-09-01",]
OctoWer2011W = COW.loc[COW.Month=="2011-10-01",]

April2012W = COW.loc[COW.Month=="2012-04-01",]
May2012W= COW.loc[COW.Month=="2012-05-01",]
June2012W= COW.loc[COW.Month=="2012-06-01",]
July2012W= COW.loc[COW.Month=="2012-07-01",]
August2012W= COW.loc[COW.Month=="2012-08-01",]
SeptemWer2012W = COW.loc[COW.Month=="2012-09-01",]
OctoWer2012W = COW.loc[COW.Month=="2012-10-01",]

April2013W = COW.loc[COW.Month=="2013-04-01",]
May2013W= COW.loc[COW.Month=="2013-05-01",]
June2013W= COW.loc[COW.Month=="2013-06-01",]
July2013W= COW.loc[COW.Month=="2013-07-01",]
August2013W= COW.loc[COW.Month=="2013-08-01",]
SeptemWer2013W = COW.loc[COW.Month=="2013-09-01",]
OctoWer2013W = COW.loc[COW.Month=="2013-10-01",]

April2014W = COW.loc[COW.Month=="2014-04-01",]
May2014W= COW.loc[COW.Month=="2014-05-01",]
June2014W= COW.loc[COW.Month=="2014-06-01",]
July2014W= COW.loc[COW.Month=="2014-07-01",]
August2014W= COW.loc[COW.Month=="2014-08-01",]
SeptemWer2014W = COW.loc[COW.Month=="2014-09-01",]
OctoWer2014W = COW.loc[COW.Month=="2014-10-01",]

April2015W = COW.loc[COW.Month=="2015-04-01",]
May2015W= COW.loc[COW.Month=="2015-05-01",]
June2015W= COW.loc[COW.Month=="2015-06-01",]
July2015W= COW.loc[COW.Month=="2015-07-01",]
August2015W= COW.loc[COW.Month=="2015-08-01",]
SeptemWer2015W = COW.loc[COW.Month=="2015-09-01",]
OctoWer2015W = COW.loc[COW.Month=="2015-10-01",]

April2016W = COW.loc[COW.Month=="2016-04-01",]
May2016W= COW.loc[COW.Month=="2016-05-01",]
June2016W= COW.loc[COW.Month=="2016-06-01",]
July2016W= COW.loc[COW.Month=="2016-07-01",]
August2016W= COW.loc[COW.Month=="2016-08-01",]
SeptemWer2016W = COW.loc[COW.Month=="2016-09-01",]
OctoWer2016W = COW.loc[COW.Month=="2016-10-01",]

April2017W = COW.loc[COW.Month=="2017-04-01",]
May2017W= COW.loc[COW.Month=="2017-05-01",]
June2017W= COW.loc[COW.Month=="2017-06-01",]
July2017W= COW.loc[COW.Month=="2017-07-01",]
August2017W= COW.loc[COW.Month=="2017-08-01",]
SeptemWer2017W = COW.loc[COW.Month=="2017-09-01",]
OctoWer2017W = COW.loc[COW.Month=="2017-10-01",]

April2018W = COW.loc[COW.Month=="2018-04-01",]
May2018W= COW.loc[COW.Month=="2018-05-01",]
June2018W= COW.loc[COW.Month=="2018-06-01",]
July2018W= COW.loc[COW.Month=="2018-07-01",]
August2018W= COW.loc[COW.Month=="2018-08-01",]
SeptemWer2018W = COW.loc[COW.Month=="2018-09-01",]
OctoWer2018W = COW.loc[COW.Month=="2018-10-01",]

# %%
COL.head()
# Out:
#            Day of Week Visitor Home Home Division  Visitor Score  Home Score  \
# Date
# 2009-04-10         Fri     PHI  COL            NL              3          10
# 2009-04-11         Sat     PHI  COL            NL              8           4
# 2009-04-12         Sun     PHI  COL            NL              7           5
# 2009-04-24         Fri     LAN  COL            NL              6           5
# 2009-04-25         Sat     LAN  COL            NL              6           5
#
#             Game Length (outs)  Day or Night  Attendance  \
# Date
# 2009-04-10                  51           1.0     49427.0
# 2009-04-11                  54           0.0     35251.0
# 2009-04-12                  54           1.0     21628.0
# 2009-04-24                  54           0.0     36151.0
# 2009-04-25                  54           0.0     31476.0
#
#             Game Length (minutes)  Visitor Homeruns  Visitor Pitchers Used  \
# Date
# ...

# %%
COL.head()
W.head()
# Out:
#            Day of Week Visitor Home Home Division  Visitor Score  Home Score  \
# Date
# 2009-04-10         Fri     PHI  COL            NL              3          10
# 2009-04-11         Sat     PHI  COL            NL              8           4
# 2009-04-12         Sun     PHI  COL            NL              7           5
# 2009-04-24         Fri     LAN  COL            NL              6           5
# 2009-04-25         Sat     LAN  COL            NL              6           5
#
#             Game Length (outs)  Day or Night  Attendance  \
# Date
# 2009-04-10                  51           1.0     49427.0
# 2009-04-11                  54           0.0     35251.0
# 2009-04-12                  54           1.0     21628.0
# 2009-04-24                  54           0.0     36151.0
# 2009-04-25                  54           0.0     31476.0
#
#             Game Length (minutes)  Visitor Homeruns  Visitor Pitchers Used  \
# Date
# ...

# %%
COL['Extra Innings']=COL['Game Length (outs)'].apply(lambda x: 0 if x <= 54 else 1)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
COL.head()
# Out:
#            Day of Week Visitor Home Home Division  Visitor Score  Home Score  \
# Date
# 2009-04-10         Fri     PHI  COL            NL              3          10
# 2009-04-11         Sat     PHI  COL            NL              8           4
# 2009-04-12         Sun     PHI  COL            NL              7           5
# 2009-04-24         Fri     LAN  COL            NL              6           5
# 2009-04-25         Sat     LAN  COL            NL              6           5
#
#             Game Length (outs)  Day or Night  Attendance  \
# Date
# 2009-04-10                  51           1.0     49427.0
# 2009-04-11                  54           0.0     35251.0
# 2009-04-12                  54           1.0     21628.0
# 2009-04-24                  54           0.0     36151.0
# 2009-04-25                  54           0.0     31476.0
#
#             Game Length (minutes)  Visitor Homeruns  Visitor Pitchers Used  \
# Date
# ...

# %%
April2009.mean()
May2009.mean()
June2009.mean()
July2009.mean()
August2009.mean()
September2009.mean()
October2009.mean()

April2010.mean()
May2010.mean()
June2010.mean()
July2010.mean()
August2010.mean()
September2010.mean()
October2010.mean()

April2011.mean()
May2011.mean()
June2011.mean()
July2011.mean()
August2011.mean()
September2011.mean()
October2011.mean()

April2012.mean()
May2012.mean()
June2012.mean()
July2012.mean()
August2012.mean()
September2012.mean()
October2012.mean()

April2013.mean()
May2013.mean()
June2013.mean()
July2013.mean()
August2013.mean()
September2013.mean()
October2013.mean()

April2014.mean()
May2014.mean()
June2014.mean()
July2014.mean()
August2014.mean()
September2014.mean()
October2014.mean()

April2015.mean()
May2015.mean()
June2015.mean()
July2015.mean()
August2015.mean()
September2015.mean()
October2015.mean()

April2016.mean()
May2016.mean()
June2016.mean()
July2016.mean()
August2016.mean()
September2016.mean()
October2016.mean()

April2017.mean()
May2017.mean()
June2017.mean()
July2017.mean()
August2017.mean()
September2017.mean()
October2017.mean()

April2018.mean()
May2018.mean()
June2018.mean()
July2018.mean()
August2018.mean()
September2018.mean()
October2018.mean()
# Out:
# ActHigh     56.833333
# ActLow      34.000000
# ActAvg      45.766667
# NormHigh    64.200000
# NormAvg.    49.466667
# NormDept    -3.700000
# SnowAmt      0.373333
# dtype: float64
# ActHigh     70.096774
# ActLow      47.032258
# ActAvg      58.838710
# NormHigh    74.064516
# NormAvg.    59.225806
# NormDept    -0.387097
# SnowAmt      0.000000
# dtype: float64
# ActHigh     75.666667
# ActLow      52.000000
# ActAvg      64.100000
# NormHigh    85.066667
# NormAvg.    68.933333
# NormDept    -4.833333
# SnowAmt      0.000000
# dtype: float64
# ActHigh     82.870968
# ActLow      57.709677
# ActAvg      70.580645
# NormHigh    91.741935
# NormAvg.    74.967742
# NormDept    -4.387097
# SnowAmt      0.000000
# dtype: float64
# ActHigh     83.612903
# ActLow      56.903226
# ActAvg      70.548387
# NormHigh    89.322581
# NormAvg.    73.258065
# NormDept    -2.709677
# SnowAmt      0.000000
# dtype: float64
# ActHigh     76.100000
# ActLow      49.766667
# ActAvg      63.266667
# ...

# %%
April2009B.mean()
May2009B.mean()
June2009B.mean()
July2009B.mean()
August2009B.mean()
September2009B.mean()
October2009B.mean()

April2010B.mean()
May2010B.mean()
June2010B.mean()
July2010B.mean()
August2010B.mean()
September2010B.mean()
October2010B.mean()

April2011B.mean()
May2011B.mean()
June2011B.mean()
July2011B.mean()
August2011B.mean()
September2011B.mean()
October2011B.mean()

April2012B.mean()
May2012B.mean()
June2012B.mean()
July2012B.mean()
August2012B.mean()
September2012B.mean()
October2012B.mean()

April2013B.mean()
May2013B.mean()
June2013B.mean()
July2013B.mean()
August2013B.mean()
September2013B.mean()
October2013B.mean()

April2014B.mean()
May2014B.mean()
June2014B.mean()
July2014B.mean()
August2014B.mean()
September2014B.mean()
October2014B.mean()

April2015B.mean()
May2015B.mean()
June2015B.mean()
July2015B.mean()
August2015B.mean()
September2015B.mean()
October2015B.mean()

April2016B.mean()
May2016B.mean()
June2016B.mean()
July2016B.mean()
August2016B.mean()
September2016B.mean()
October2016B.mean()

April2017B.mean()
May2017B.mean()
June2017B.mean()
July2017B.mean()
August2017B.mean()
September2017B.mean()
October2017B.mean()

April2018B.mean()
May2018B.mean()
June2018B.mean()
July2018B.mean()
August2018B.mean()
September2018B.mean()
October2018B.mean()
# Out:
# Visitor Score                5.555556
# Home Score                   6.777778
# Game Length (outs)          52.666667
# Day or Night                 0.444444
# Attendance               29702.111111
# Game Length (minutes)      185.222222
# Visitor Homeruns             1.000000
# Visitor Pitchers Used        4.222222
# Visitor Errors               0.222222
# Home Homeruns                1.333333
# Home Pitchers Used           4.444444
# Home Errors                  0.444444
# dtype: float64
# Visitor Score                6.142857
# Home Score                   5.214286
# Game Length (outs)          53.071429
# Day or Night                 0.428571
# Attendance               26195.714286
# Game Length (minutes)      178.714286
# Visitor Homeruns             0.642857
# Visitor Pitchers Used        3.785714
# Visitor Errors               0.857143
# Home Homeruns                1.142857
# Home Pitchers Used           3.857143
# Home Errors                  0.857143
# dtype: float64
# ...

# %%
COL['Game Length (minutes)'].mean()
# Out:
# 187.3740740740741

# %%
COL.head()
W.head()
# Out:
#            Day of Week Visitor Home Home Division  Visitor Score  Home Score  \
# Date
# 2009-04-10         Fri     PHI  COL            NL              3          10
# 2009-04-11         Sat     PHI  COL            NL              8           4
# 2009-04-12         Sun     PHI  COL            NL              7           5
# 2009-04-24         Fri     LAN  COL            NL              6           5
# 2009-04-25         Sat     LAN  COL            NL              6           5
#
#             Game Length (outs)  Day or Night  Attendance  \
# Date
# 2009-04-10                  51           1.0     49427.0
# 2009-04-11                  54           0.0     35251.0
# 2009-04-12                  54           1.0     21628.0
# 2009-04-24                  54           0.0     36151.0
# 2009-04-25                  54           0.0     31476.0
#
#             Game Length (minutes)  Visitor Homeruns  Visitor Pitchers Used  \
# Date
# ...

# %%
COL['deltaGame']= COL['Game Length (minutes)'] - (COL['Game Length (minutes)'].mean())
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
COL.head()
# Out:
#            Day of Week Visitor Home Home Division  Visitor Score  Home Score  \
# Date
# 2009-04-10         Fri     PHI  COL            NL              3          10
# 2009-04-11         Sat     PHI  COL            NL              8           4
# 2009-04-12         Sun     PHI  COL            NL              7           5
# 2009-04-24         Fri     LAN  COL            NL              6           5
# 2009-04-25         Sat     LAN  COL            NL              6           5
#
#             Game Length (outs)  Day or Night  Attendance  \
# Date
# 2009-04-10                  51           1.0     49427.0
# 2009-04-11                  54           0.0     35251.0
# 2009-04-12                  54           1.0     21628.0
# 2009-04-24                  54           0.0     36151.0
# 2009-04-25                  54           0.0     31476.0
#
#             Game Length (minutes)  Visitor Homeruns  Visitor Pitchers Used  \
# Date
# ...

# %%
COW.head()
# Out:
#            Day of Week Visitor Home Home Division  Visitor Score  Home Score  \
# Date
# 2009-04-10         Fri     PHI  COL            NL              3          10
# 2009-04-11         Sat     PHI  COL            NL              8           4
# 2009-04-12         Sun     PHI  COL            NL              7           5
# 2009-04-24         Fri     LAN  COL            NL              6           5
# 2009-04-25         Sat     LAN  COL            NL              6           5
#
#             Game Length (outs)  Day or Night  Attendance  \
# Date
# 2009-04-10                  51           1.0     49427.0
# 2009-04-11                  54           0.0     35251.0
# 2009-04-12                  54           1.0     21628.0
# 2009-04-24                  54           0.0     36151.0
# 2009-04-25                  54           0.0     31476.0
#
#             Game Length (minutes)  ...  Home Errors      Month  ActHigh  \
# Date                               ...
# ...
